# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# Set the size of the 3D structure
slice_size = (100, 100)  # Each slice is 100x100 pixels
num_slices = 100         # Number of slices
num_structures_per_case = 800  # Number of structures for each case

# Pore sizes and their corresponding names
pore_sizes = [10]
density_labels = ['dataset']

# Number of pores for each density
density_pores = {
    'dataset': (10, 40),    # Low density: 3-5 pores
    #'medium_density': (6, 10), # Medium density: 6-10 pores
    #'high_density': (11, 16)   # High density: 11-16 pores
}

# Directory to save the structures
output_folder = "3D_square"
os.makedirs(output_folder, exist_ok=True)

# Function to check if a rectangular pore overlaps with existing pores
def is_overlapping(existing_mask, start_row, start_col, pore_height, pore_width):
    # Check if the area where the pore would be placed is already occupied (non-zero)
    return np.any(existing_mask[start_row:start_row + pore_height, start_col:start_col + pore_width] == 0)

# Function to place multiple non-overlapping rectangular pores in 3D structure
def generate_rectangular_pores_3D(pore_height, pore_width, num_pores):
    # Create a 3D array (num_slices x height x width) filled with ones (white background, representing material)
    structure = np.ones((num_slices, slice_size[0], slice_size[1]))

    for _ in range(num_pores):
        pore_placed = False
        while not pore_placed:
            # Randomly position the pore in the slice
            start_row = np.random.randint(0, slice_size[0] - pore_height)
            start_col = np.random.randint(0, slice_size[1] - pore_width)

            # Check for overlap with existing pores
            if not is_overlapping(structure[0], start_row, start_col, pore_height, pore_width):
                # If there's no overlap, place the same pore in all slices (continuous pipe)
                structure[:, start_row:start_row + pore_height, start_col:start_col + pore_width] = 0  # Pore is black (0)
                pore_placed = True

    return structure

# Generate and save 3D structures
for pore_size in pore_sizes:
    for density_label in density_labels:
        # Get the number of pores based on the density
        min_pores, max_pores = density_pores[density_label]

        # Create a folder for this pore size and density distribution
        case_folder = os.path.join(output_folder, f"pore_{pore_size}x{pore_size}", density_label)
        os.makedirs(case_folder, exist_ok=True)

        for structure_idx in range(num_structures_per_case):
            # Randomly generate the number of pores for this structure
            num_pores = np.random.randint(min_pores, max_pores + 1)

            # Generate the 3D structure with non-overlapping rectangular pores
            structure = generate_rectangular_pores_3D(pore_size, pore_size, num_pores)

            # Create a folder for each 3D structure
            structure_folder = os.path.join(case_folder, f"structure_{structure_idx:05d}")
            os.makedirs(structure_folder, exist_ok=True)

            # Save each slice of the 3D structure as a separate image
            for slice_idx in range(num_slices):
                slice_image = structure[slice_idx]

                # Save the slice as a binary BMP file
                slice_filename = os.path.join(structure_folder, f"slice_{slice_idx+1:03d}.bmp")
                plt.imsave(slice_filename, slice_image, cmap='gray', format='bmp', vmin=0, vmax=1)

            print(f"Saved 3D structure {structure_idx+1:05d} with {num_pores} pores (pore size {pore_size}x{pore_size}, {density_label}) in '{structure_folder}'.")

print(f"Generated all 3D porous material structures in '{output_folder}' folder.")
# Out:
# Saved 3D structure 00001 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00000'.
# Saved 3D structure 00002 with 32 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00001'.
# Saved 3D structure 00003 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00002'.
# Saved 3D structure 00004 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00003'.
# Saved 3D structure 00005 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00004'.
# Saved 3D structure 00006 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00005'.
# Saved 3D structure 00007 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00006'.
# Saved 3D structure 00008 with 15 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00007'.
# Saved 3D structure 00009 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00008'.
# Saved 3D structure 00010 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00009'.
# Saved 3D structure 00011 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00010'.
# Saved 3D structure 00012 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00011'.
# Saved 3D structure 00013 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00012'.
# Saved 3D structure 00014 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00013'.
# Saved 3D structure 00015 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00014'.
# Saved 3D structure 00016 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00015'.
# Saved 3D structure 00017 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00016'.
# Saved 3D structure 00018 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00017'.
# Saved 3D structure 00019 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00018'.
# Saved 3D structure 00020 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00019'.
# Saved 3D structure 00021 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00020'.
# Saved 3D structure 00022 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00021'.
# Saved 3D structure 00023 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00022'.
# Saved 3D structure 00024 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00023'.
# Saved 3D structure 00025 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00024'.
# Saved 3D structure 00026 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00025'.
# Saved 3D structure 00027 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00026'.
# Saved 3D structure 00028 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00027'.
# Saved 3D structure 00029 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00028'.
# Saved 3D structure 00030 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00029'.
# Saved 3D structure 00031 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00030'.
# Saved 3D structure 00032 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00031'.
# Saved 3D structure 00033 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00032'.
# Saved 3D structure 00034 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00033'.
# Saved 3D structure 00035 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00034'.
# Saved 3D structure 00036 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00035'.
# Saved 3D structure 00037 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00036'.
# Saved 3D structure 00038 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00037'.
# Saved 3D structure 00039 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00038'.
# Saved 3D structure 00040 with 14 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00039'.
# Saved 3D structure 00041 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00040'.
# Saved 3D structure 00042 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00041'.
# Saved 3D structure 00043 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00042'.
# Saved 3D structure 00044 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00043'.
# Saved 3D structure 00045 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00044'.
# Saved 3D structure 00046 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00045'.
# Saved 3D structure 00047 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00046'.
# Saved 3D structure 00048 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00047'.
# Saved 3D structure 00049 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00048'.
# Saved 3D structure 00050 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00049'.
# Saved 3D structure 00051 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00050'.
# Saved 3D structure 00052 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00051'.
# Saved 3D structure 00053 with 15 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00052'.
# Saved 3D structure 00054 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00053'.
# Saved 3D structure 00055 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00054'.
# Saved 3D structure 00056 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00055'.
# Saved 3D structure 00057 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00056'.
# Saved 3D structure 00058 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00057'.
# Saved 3D structure 00059 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00058'.
# Saved 3D structure 00060 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00059'.
# Saved 3D structure 00061 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00060'.
# Saved 3D structure 00062 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00061'.
# Saved 3D structure 00063 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00062'.
# Saved 3D structure 00064 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00063'.
# Saved 3D structure 00065 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00064'.
# Saved 3D structure 00066 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00065'.
# Saved 3D structure 00067 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00066'.
# Saved 3D structure 00068 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00067'.
# Saved 3D structure 00069 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00068'.
# Saved 3D structure 00070 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00069'.
# Saved 3D structure 00071 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00070'.
# Saved 3D structure 00072 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00071'.
# Saved 3D structure 00073 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00072'.
# Saved 3D structure 00074 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00073'.
# Saved 3D structure 00075 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00074'.
# Saved 3D structure 00076 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00075'.
# Saved 3D structure 00077 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00076'.
# Saved 3D structure 00078 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00077'.
# Saved 3D structure 00079 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00078'.
# Saved 3D structure 00080 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00079'.
# Saved 3D structure 00081 with 15 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00080'.
# Saved 3D structure 00082 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00081'.
# Saved 3D structure 00083 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00082'.
# Saved 3D structure 00084 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00083'.
# Saved 3D structure 00085 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00084'.
# Saved 3D structure 00086 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00085'.
# Saved 3D structure 00087 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00086'.
# Saved 3D structure 00088 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00087'.
# Saved 3D structure 00089 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00088'.
# Saved 3D structure 00090 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00089'.
# Saved 3D structure 00091 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00090'.
# Saved 3D structure 00092 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00091'.
# Saved 3D structure 00093 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00092'.
# Saved 3D structure 00094 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00093'.
# Saved 3D structure 00095 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00094'.
# Saved 3D structure 00096 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00095'.
# Saved 3D structure 00097 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00096'.
# Saved 3D structure 00098 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00097'.
# Saved 3D structure 00099 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00098'.
# Saved 3D structure 00100 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00099'.
# Saved 3D structure 00101 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00100'.
# Saved 3D structure 00102 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00101'.
# Saved 3D structure 00103 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00102'.
# Saved 3D structure 00104 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00103'.
# Saved 3D structure 00105 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00104'.
# Saved 3D structure 00106 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00105'.
# Saved 3D structure 00107 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00106'.
# Saved 3D structure 00108 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00107'.
# Saved 3D structure 00109 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00108'.
# Saved 3D structure 00110 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00109'.
# Saved 3D structure 00111 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00110'.
# Saved 3D structure 00112 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00111'.
# Saved 3D structure 00113 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00112'.
# Saved 3D structure 00114 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00113'.
# Saved 3D structure 00115 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00114'.
# Saved 3D structure 00116 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00115'.
# Saved 3D structure 00117 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00116'.
# Saved 3D structure 00118 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00117'.
# Saved 3D structure 00119 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00118'.
# Saved 3D structure 00120 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00119'.
# Saved 3D structure 00121 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00120'.
# Saved 3D structure 00122 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00121'.
# Saved 3D structure 00123 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00122'.
# Saved 3D structure 00124 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00123'.
# Saved 3D structure 00125 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00124'.
# Saved 3D structure 00126 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00125'.
# Saved 3D structure 00127 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00126'.
# Saved 3D structure 00128 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00127'.
# Saved 3D structure 00129 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00128'.
# Saved 3D structure 00130 with 14 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00129'.
# Saved 3D structure 00131 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00130'.
# Saved 3D structure 00132 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00131'.
# Saved 3D structure 00133 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00132'.
# Saved 3D structure 00134 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00133'.
# Saved 3D structure 00135 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00134'.
# Saved 3D structure 00136 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00135'.
# Saved 3D structure 00137 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00136'.
# Saved 3D structure 00138 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00137'.
# Saved 3D structure 00139 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00138'.
# Saved 3D structure 00140 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00139'.
# Saved 3D structure 00141 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00140'.
# Saved 3D structure 00142 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00141'.
# Saved 3D structure 00143 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00142'.
# Saved 3D structure 00144 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00143'.
# Saved 3D structure 00145 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00144'.
# Saved 3D structure 00146 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00145'.
# Saved 3D structure 00147 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00146'.
# Saved 3D structure 00148 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00147'.
# Saved 3D structure 00149 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00148'.
# Saved 3D structure 00150 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00149'.
# Saved 3D structure 00151 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00150'.
# Saved 3D structure 00152 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00151'.
# Saved 3D structure 00153 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00152'.
# Saved 3D structure 00154 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00153'.
# Saved 3D structure 00155 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00154'.
# Saved 3D structure 00156 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00155'.
# Saved 3D structure 00157 with 15 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00156'.
# Saved 3D structure 00158 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00157'.
# Saved 3D structure 00159 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00158'.
# Saved 3D structure 00160 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00159'.
# Saved 3D structure 00161 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00160'.
# Saved 3D structure 00162 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00161'.
# Saved 3D structure 00163 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00162'.
# Saved 3D structure 00164 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00163'.
# Saved 3D structure 00165 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00164'.
# Saved 3D structure 00166 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00165'.
# Saved 3D structure 00167 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00166'.
# Saved 3D structure 00168 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00167'.
# Saved 3D structure 00169 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00168'.
# Saved 3D structure 00170 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00169'.
# Saved 3D structure 00171 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00170'.
# Saved 3D structure 00172 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00171'.
# Saved 3D structure 00173 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00172'.
# Saved 3D structure 00174 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00173'.
# Saved 3D structure 00175 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00174'.
# Saved 3D structure 00176 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00175'.
# Saved 3D structure 00177 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00176'.
# Saved 3D structure 00178 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00177'.
# Saved 3D structure 00179 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00178'.
# Saved 3D structure 00180 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00179'.
# Saved 3D structure 00181 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00180'.
# Saved 3D structure 00182 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00181'.
# Saved 3D structure 00183 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00182'.
# Saved 3D structure 00184 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00183'.
# Saved 3D structure 00185 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00184'.
# Saved 3D structure 00186 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00185'.
# Saved 3D structure 00187 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00186'.
# Saved 3D structure 00188 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00187'.
# Saved 3D structure 00189 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00188'.
# Saved 3D structure 00190 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00189'.
# Saved 3D structure 00191 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00190'.
# Saved 3D structure 00192 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00191'.
# Saved 3D structure 00193 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00192'.
# Saved 3D structure 00194 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00193'.
# Saved 3D structure 00195 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00194'.
# Saved 3D structure 00196 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00195'.
# Saved 3D structure 00197 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00196'.
# Saved 3D structure 00198 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00197'.
# Saved 3D structure 00199 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00198'.
# Saved 3D structure 00200 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00199'.
# Saved 3D structure 00201 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00200'.
# Saved 3D structure 00202 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00201'.
# Saved 3D structure 00203 with 32 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00202'.
# Saved 3D structure 00204 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00203'.
# Saved 3D structure 00205 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00204'.
# Saved 3D structure 00206 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00205'.
# Saved 3D structure 00207 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00206'.
# Saved 3D structure 00208 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00207'.
# Saved 3D structure 00209 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00208'.
# Saved 3D structure 00210 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00209'.
# Saved 3D structure 00211 with 32 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00210'.
# Saved 3D structure 00212 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00211'.
# Saved 3D structure 00213 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00212'.
# Saved 3D structure 00214 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00213'.
# Saved 3D structure 00215 with 14 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00214'.
# Saved 3D structure 00216 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00215'.
# Saved 3D structure 00217 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00216'.
# Saved 3D structure 00218 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00217'.
# Saved 3D structure 00219 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00218'.
# Saved 3D structure 00220 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00219'.
# Saved 3D structure 00221 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00220'.
# Saved 3D structure 00222 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00221'.
# Saved 3D structure 00223 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00222'.
# Saved 3D structure 00224 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00223'.
# Saved 3D structure 00225 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00224'.
# Saved 3D structure 00226 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00225'.
# Saved 3D structure 00227 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00226'.
# Saved 3D structure 00228 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00227'.
# Saved 3D structure 00229 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00228'.
# Saved 3D structure 00230 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00229'.
# Saved 3D structure 00231 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00230'.
# Saved 3D structure 00232 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00231'.
# Saved 3D structure 00233 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00232'.
# Saved 3D structure 00234 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00233'.
# Saved 3D structure 00235 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00234'.
# Saved 3D structure 00236 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00235'.
# Saved 3D structure 00237 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00236'.
# Saved 3D structure 00238 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00237'.
# Saved 3D structure 00239 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00238'.
# Saved 3D structure 00240 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00239'.
# Saved 3D structure 00241 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00240'.
# Saved 3D structure 00242 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00241'.
# Saved 3D structure 00243 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00242'.
# Saved 3D structure 00244 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00243'.
# Saved 3D structure 00245 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00244'.
# Saved 3D structure 00246 with 15 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00245'.
# Saved 3D structure 00247 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00246'.
# Saved 3D structure 00248 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00247'.
# Saved 3D structure 00249 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00248'.
# Saved 3D structure 00250 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00249'.
# Saved 3D structure 00251 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00250'.
# Saved 3D structure 00252 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00251'.
# Saved 3D structure 00253 with 32 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00252'.
# Saved 3D structure 00254 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00253'.
# Saved 3D structure 00255 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00254'.
# Saved 3D structure 00256 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00255'.
# Saved 3D structure 00257 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00256'.
# Saved 3D structure 00258 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00257'.
# Saved 3D structure 00259 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00258'.
# Saved 3D structure 00260 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00259'.
# Saved 3D structure 00261 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00260'.
# Saved 3D structure 00262 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00261'.
# Saved 3D structure 00263 with 14 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00262'.
# Saved 3D structure 00264 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00263'.
# Saved 3D structure 00265 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00264'.
# Saved 3D structure 00266 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00265'.
# Saved 3D structure 00267 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00266'.
# Saved 3D structure 00268 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00267'.
# Saved 3D structure 00269 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00268'.
# Saved 3D structure 00270 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00269'.
# Saved 3D structure 00271 with 14 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00270'.
# Saved 3D structure 00272 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00271'.
# Saved 3D structure 00273 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00272'.
# Saved 3D structure 00274 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00273'.
# Saved 3D structure 00275 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00274'.
# Saved 3D structure 00276 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00275'.
# Saved 3D structure 00277 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00276'.
# Saved 3D structure 00278 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00277'.
# Saved 3D structure 00279 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00278'.
# Saved 3D structure 00280 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00279'.
# Saved 3D structure 00281 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00280'.
# Saved 3D structure 00282 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00281'.
# Saved 3D structure 00283 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00282'.
# Saved 3D structure 00284 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00283'.
# Saved 3D structure 00285 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00284'.
# Saved 3D structure 00286 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00285'.
# Saved 3D structure 00287 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00286'.
# Saved 3D structure 00288 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00287'.
# Saved 3D structure 00289 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00288'.
# Saved 3D structure 00290 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00289'.
# Saved 3D structure 00291 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00290'.
# Saved 3D structure 00292 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00291'.
# Saved 3D structure 00293 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00292'.
# Saved 3D structure 00294 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00293'.
# Saved 3D structure 00295 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00294'.
# Saved 3D structure 00296 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00295'.
# Saved 3D structure 00297 with 15 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00296'.
# Saved 3D structure 00298 with 15 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00297'.
# Saved 3D structure 00299 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00298'.
# Saved 3D structure 00300 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00299'.
# Saved 3D structure 00301 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00300'.
# Saved 3D structure 00302 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00301'.
# Saved 3D structure 00303 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00302'.
# Saved 3D structure 00304 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00303'.
# Saved 3D structure 00305 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00304'.
# Saved 3D structure 00306 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00305'.
# Saved 3D structure 00307 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00306'.
# Saved 3D structure 00308 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00307'.
# Saved 3D structure 00309 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00308'.
# Saved 3D structure 00310 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00309'.
# Saved 3D structure 00311 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00310'.
# Saved 3D structure 00312 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00311'.
# Saved 3D structure 00313 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00312'.
# Saved 3D structure 00314 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00313'.
# Saved 3D structure 00315 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00314'.
# Saved 3D structure 00316 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00315'.
# Saved 3D structure 00317 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00316'.
# Saved 3D structure 00318 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00317'.
# Saved 3D structure 00319 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00318'.
# Saved 3D structure 00320 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00319'.
# Saved 3D structure 00321 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00320'.
# Saved 3D structure 00322 with 15 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00321'.
# Saved 3D structure 00323 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00322'.
# Saved 3D structure 00324 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00323'.
# Saved 3D structure 00325 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00324'.
# Saved 3D structure 00326 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00325'.
# Saved 3D structure 00327 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00326'.
# Saved 3D structure 00328 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00327'.
# Saved 3D structure 00329 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00328'.
# Saved 3D structure 00330 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00329'.
# Saved 3D structure 00331 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00330'.
# Saved 3D structure 00332 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00331'.
# Saved 3D structure 00333 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00332'.
# Saved 3D structure 00334 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00333'.
# Saved 3D structure 00335 with 15 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00334'.
# Saved 3D structure 00336 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00335'.
# Saved 3D structure 00337 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00336'.
# Saved 3D structure 00338 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00337'.
# Saved 3D structure 00339 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00338'.
# Saved 3D structure 00340 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00339'.
# Saved 3D structure 00341 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00340'.
# Saved 3D structure 00342 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00341'.
# Saved 3D structure 00343 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00342'.
# Saved 3D structure 00344 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00343'.
# Saved 3D structure 00345 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00344'.
# Saved 3D structure 00346 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00345'.
# Saved 3D structure 00347 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00346'.
# Saved 3D structure 00348 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00347'.
# Saved 3D structure 00349 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00348'.
# Saved 3D structure 00350 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00349'.
# Saved 3D structure 00351 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00350'.
# Saved 3D structure 00352 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00351'.
# Saved 3D structure 00353 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00352'.
# Saved 3D structure 00354 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00353'.
# Saved 3D structure 00355 with 15 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00354'.
# Saved 3D structure 00356 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00355'.
# Saved 3D structure 00357 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00356'.
# Saved 3D structure 00358 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00357'.
# Saved 3D structure 00359 with 15 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00358'.
# Saved 3D structure 00360 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00359'.
# Saved 3D structure 00361 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00360'.
# Saved 3D structure 00362 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00361'.
# Saved 3D structure 00363 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00362'.
# Saved 3D structure 00364 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00363'.
# Saved 3D structure 00365 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00364'.
# Saved 3D structure 00366 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00365'.
# Saved 3D structure 00367 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00366'.
# Saved 3D structure 00368 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00367'.
# Saved 3D structure 00369 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00368'.
# Saved 3D structure 00370 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00369'.
# Saved 3D structure 00371 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00370'.
# Saved 3D structure 00372 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00371'.
# Saved 3D structure 00373 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00372'.
# Saved 3D structure 00374 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00373'.
# Saved 3D structure 00375 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00374'.
# Saved 3D structure 00376 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00375'.
# Saved 3D structure 00377 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00376'.
# Saved 3D structure 00378 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00377'.
# Saved 3D structure 00379 with 14 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00378'.
# Saved 3D structure 00380 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00379'.
# Saved 3D structure 00381 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00380'.
# Saved 3D structure 00382 with 38 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00381'.
# Saved 3D structure 00383 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00382'.
# Saved 3D structure 00384 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00383'.
# Saved 3D structure 00385 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00384'.
# Saved 3D structure 00386 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00385'.
# Saved 3D structure 00387 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00386'.
# Saved 3D structure 00388 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00387'.
# Saved 3D structure 00389 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00388'.
# Saved 3D structure 00390 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00389'.
# Saved 3D structure 00391 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00390'.
# Saved 3D structure 00392 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00391'.
# Saved 3D structure 00393 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00392'.
# Saved 3D structure 00394 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00393'.
# Saved 3D structure 00395 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00394'.
# Saved 3D structure 00396 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00395'.
# Saved 3D structure 00397 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00396'.
# Saved 3D structure 00398 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00397'.
# Saved 3D structure 00399 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00398'.
# Saved 3D structure 00400 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00399'.
# Saved 3D structure 00401 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00400'.
# Saved 3D structure 00402 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00401'.
# Saved 3D structure 00403 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00402'.
# Saved 3D structure 00404 with 32 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00403'.
# Saved 3D structure 00405 with 32 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00404'.
# Saved 3D structure 00406 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00405'.
# Saved 3D structure 00407 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00406'.
# Saved 3D structure 00408 with 14 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00407'.
# Saved 3D structure 00409 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00408'.
# Saved 3D structure 00410 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00409'.
# ...
# Saved 3D structure 00665 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00664'.
# Saved 3D structure 00666 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00665'.
# Saved 3D structure 00667 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00666'.
# Saved 3D structure 00668 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00667'.
# Saved 3D structure 00669 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00668'.
# Saved 3D structure 00670 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00669'.
# Saved 3D structure 00671 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00670'.
# Saved 3D structure 00672 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00671'.
# Saved 3D structure 00673 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00672'.
# Saved 3D structure 00674 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00673'.
# Saved 3D structure 00675 with 32 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00674'.
# Saved 3D structure 00676 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00675'.
# Saved 3D structure 00677 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00676'.
# Saved 3D structure 00678 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00677'.
# Saved 3D structure 00679 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00678'.
# Saved 3D structure 00680 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00679'.
# Saved 3D structure 00681 with 32 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00680'.
# Saved 3D structure 00682 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00681'.
# Saved 3D structure 00683 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00682'.
# Saved 3D structure 00684 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00683'.
# Saved 3D structure 00685 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00684'.
# Saved 3D structure 00686 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00685'.
# Saved 3D structure 00687 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00686'.
# Saved 3D structure 00688 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00687'.
# Saved 3D structure 00689 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00688'.
# Saved 3D structure 00690 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00689'.
# Saved 3D structure 00691 with 14 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00690'.
# Saved 3D structure 00692 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00691'.
# Saved 3D structure 00693 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00692'.
# Saved 3D structure 00694 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00693'.
# Saved 3D structure 00695 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00694'.
# Saved 3D structure 00696 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00695'.
# Saved 3D structure 00697 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00696'.
# Saved 3D structure 00698 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00697'.
# Saved 3D structure 00699 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00698'.
# Saved 3D structure 00700 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00699'.
# Saved 3D structure 00701 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00700'.
# Saved 3D structure 00702 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00701'.
# Saved 3D structure 00703 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00702'.
# Saved 3D structure 00704 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00703'.
# Saved 3D structure 00705 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00704'.
# Saved 3D structure 00706 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00705'.
# Saved 3D structure 00707 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00706'.
# Saved 3D structure 00708 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00707'.
# Saved 3D structure 00709 with 23 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00708'.
# Saved 3D structure 00710 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00709'.
# Saved 3D structure 00711 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00710'.
# Saved 3D structure 00712 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00711'.
# Saved 3D structure 00713 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00712'.
# Saved 3D structure 00714 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00713'.
# Saved 3D structure 00715 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00714'.
# Saved 3D structure 00716 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00715'.
# Saved 3D structure 00717 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00716'.
# Saved 3D structure 00718 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00717'.
# Saved 3D structure 00719 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00718'.
# Saved 3D structure 00720 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00719'.
# Saved 3D structure 00721 with 20 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00720'.
# Saved 3D structure 00722 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00721'.
# Saved 3D structure 00723 with 29 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00722'.
# Saved 3D structure 00724 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00723'.
# Saved 3D structure 00725 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00724'.
# Saved 3D structure 00726 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00725'.
# Saved 3D structure 00727 with 15 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00726'.
# Saved 3D structure 00728 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00727'.
# Saved 3D structure 00729 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00728'.
# Saved 3D structure 00730 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00729'.
# Saved 3D structure 00731 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00730'.
# Saved 3D structure 00732 with 36 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00731'.
# Saved 3D structure 00733 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00732'.
# Saved 3D structure 00734 with 32 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00733'.
# Saved 3D structure 00735 with 35 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00734'.
# Saved 3D structure 00736 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00735'.
# Saved 3D structure 00737 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00736'.
# Saved 3D structure 00738 with 27 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00737'.
# Saved 3D structure 00739 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00738'.
# Saved 3D structure 00740 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00739'.
# Saved 3D structure 00741 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00740'.
# Saved 3D structure 00742 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00741'.
# Saved 3D structure 00743 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00742'.
# Saved 3D structure 00744 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00743'.
# Saved 3D structure 00745 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00744'.
# Saved 3D structure 00746 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00745'.
# Saved 3D structure 00747 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00746'.
# Saved 3D structure 00748 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00747'.
# Saved 3D structure 00749 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00748'.
# Saved 3D structure 00750 with 26 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00749'.
# Saved 3D structure 00751 with 32 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00750'.
# Saved 3D structure 00752 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00751'.
# Saved 3D structure 00753 with 15 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00752'.
# Saved 3D structure 00754 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00753'.
# Saved 3D structure 00755 with 25 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00754'.
# Saved 3D structure 00756 with 39 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00755'.
# Saved 3D structure 00757 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00756'.
# Saved 3D structure 00758 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00757'.
# Saved 3D structure 00759 with 21 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00758'.
# Saved 3D structure 00760 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00759'.
# Saved 3D structure 00761 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00760'.
# Saved 3D structure 00762 with 22 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00761'.
# Saved 3D structure 00763 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00762'.
# Saved 3D structure 00764 with 11 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00763'.
# Saved 3D structure 00765 with 24 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00764'.
# Saved 3D structure 00766 with 32 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00765'.
# Saved 3D structure 00767 with 17 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00766'.
# Saved 3D structure 00768 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00767'.
# Saved 3D structure 00769 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00768'.
# Saved 3D structure 00770 with 16 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00769'.
# Saved 3D structure 00771 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00770'.
# Saved 3D structure 00772 with 13 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00771'.
# Saved 3D structure 00773 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00772'.
# Saved 3D structure 00774 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00773'.
# Saved 3D structure 00775 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00774'.
# Saved 3D structure 00776 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00775'.
# Saved 3D structure 00777 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00776'.
# Saved 3D structure 00778 with 32 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00777'.
# Saved 3D structure 00779 with 37 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00778'.
# Saved 3D structure 00780 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00779'.
# Saved 3D structure 00781 with 14 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00780'.
# Saved 3D structure 00782 with 33 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00781'.
# Saved 3D structure 00783 with 34 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00782'.
# Saved 3D structure 00784 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00783'.
# Saved 3D structure 00785 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00784'.
# Saved 3D structure 00786 with 30 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00785'.
# Saved 3D structure 00787 with 18 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00786'.
# Saved 3D structure 00788 with 14 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00787'.
# Saved 3D structure 00789 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00788'.
# Saved 3D structure 00790 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00789'.
# Saved 3D structure 00791 with 28 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00790'.
# Saved 3D structure 00792 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00791'.
# Saved 3D structure 00793 with 12 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00792'.
# Saved 3D structure 00794 with 19 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00793'.
# Saved 3D structure 00795 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00794'.
# Saved 3D structure 00796 with 40 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00795'.
# Saved 3D structure 00797 with 31 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00796'.
# Saved 3D structure 00798 with 14 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00797'.
# Saved 3D structure 00799 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00798'.
# Saved 3D structure 00800 with 10 pores (pore size 10x10, dataset) in '3D_square/pore_10x10/dataset/structure_00799'.
# Generated all 3D porous material structures in '3D_square' folder.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# Set the size of the 3D structure
slice_size = (100, 100)  # Each slice is 100x100 pixels
num_slices = 100         # Number of slices
num_structures_per_case = 200  # Number of structures for each case

# Pore sizes and their corresponding names
pore_sizes = [12]
density_labels = ['low_density', 'medium_density', 'high_density']

# Number of pores for each density
density_pores = {
    'low_density': (13, 15),    # Low density: 3-5 pores
    'medium_density': (16, 20), # Medium density: 6-10 pores
    'high_density': (21, 25)   # High density: 11-16 pores
}

# Directory to save the structures
output_folder = "3D_cirlinder"
os.makedirs(output_folder, exist_ok=True)

# Function to check if a circular pore overlaps with existing pores
def is_overlapping(existing_mask, center_row, center_col, radius):
    # Create a grid of points and check if any point within the circle overlaps
    y, x = np.ogrid[-radius:radius+1, -radius:radius+1]
    mask = x**2 + y**2 <= radius**2

    # Extract the area where the circle would be placed
    existing_area = existing_mask[max(0, center_row - radius):min(existing_mask.shape[0], center_row + radius + 1),
                                  max(0, center_col - radius):min(existing_mask.shape[1], center_col + radius + 1)]
    
    return np.any(existing_area[mask])

# Function to place multiple non-overlapping cylindrical pores in 3D structure
def generate_cylindrical_pores_3D(radius, num_pores):
    # Create a 3D array (num_slices x height x width) filled with zeros (black background)
    structure = np.zeros((num_slices, slice_size[0], slice_size[1]))

    for _ in range(num_pores):
        pore_placed = False
        while not pore_placed:
            # Randomly position the center of the cylindrical pore in the first slice
            center_row = np.random.randint(radius, slice_size[0] - radius)
            center_col = np.random.randint(radius, slice_size[1] - radius)

            # Check for overlap with existing pores in the first slice
            if not is_overlapping(structure[0], center_row, center_col, radius):
                # Create a mask for the cylindrical pore (same circle repeated in each slice)
                y, x = np.ogrid[-radius:radius+1, -radius:radius+1]
                mask = x**2 + y**2 <= radius**2

                # Place the cylindrical pore across all slices
                for slice_idx in range(num_slices):
                    structure[slice_idx, center_row - radius:center_row + radius + 1, center_col - radius:center_col + radius + 1][mask] = 1  # Pore is white (1)

                pore_placed = True

    return structure

# Generate and save 3D structures
for pore_size in pore_sizes:
    for density_label in density_labels:
        # Get the number of pores based on the density
        min_pores, max_pores = density_pores[density_label]

        # Create a folder for this pore size and density distribution
        case_folder = os.path.join(output_folder, f"pore_{pore_size}x{pore_size}", density_label)
        os.makedirs(case_folder, exist_ok=True)

        for structure_idx in range(num_structures_per_case):
            # Randomly generate the number of pores for this structure
            num_pores = np.random.randint(min_pores, max_pores + 1)

            # Generate the 3D structure with non-overlapping cylindrical pores
            radius = pore_size // 2
            structure = generate_cylindrical_pores_3D(radius, num_pores)

            # Create a folder for each 3D structure
            structure_folder = os.path.join(case_folder, f"structure_{structure_idx+1:03d}")
            os.makedirs(structure_folder, exist_ok=True)

            # Save each slice of the 3D structure as a separate image
            for slice_idx in range(num_slices):
                slice_image = structure[slice_idx]

                # Save the slice as a BMP file
                slice_filename = os.path.join(structure_folder, f"slice_{slice_idx+1:03d}.bmp")
                plt.imsave(slice_filename, slice_image, cmap='gray', format='bmp')

            print(f"Saved 3D structure {structure_idx+1:03d} with {num_pores} cylindrical pores (pore size {pore_size}, {density_label}) in '{structure_folder}'.")

print(f"Generated all 3D porous material structures with cylindrical pores in '{output_folder}' folder.")
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.
# Saved 3D structure 001 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_001'.
# Saved 3D structure 002 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_002'.
# Saved 3D structure 003 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_003'.
# Saved 3D structure 004 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_004'.
# Saved 3D structure 005 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_005'.
# Saved 3D structure 006 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_006'.
# Saved 3D structure 007 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_007'.
# Saved 3D structure 008 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_008'.
# Saved 3D structure 009 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_009'.
# Saved 3D structure 010 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_010'.
# Saved 3D structure 011 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_011'.
# Saved 3D structure 012 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_012'.
# Saved 3D structure 013 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_013'.
# Saved 3D structure 014 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_014'.
# Saved 3D structure 015 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_015'.
# Saved 3D structure 016 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_016'.
# Saved 3D structure 017 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_017'.
# Saved 3D structure 018 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_018'.
# Saved 3D structure 019 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_019'.
# Saved 3D structure 020 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_020'.
# Saved 3D structure 021 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_021'.
# Saved 3D structure 022 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_022'.
# Saved 3D structure 023 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_023'.
# Saved 3D structure 024 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_024'.
# Saved 3D structure 025 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_025'.
# Saved 3D structure 026 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_026'.
# Saved 3D structure 027 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_027'.
# Saved 3D structure 028 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_028'.
# Saved 3D structure 029 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_029'.
# Saved 3D structure 030 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_030'.
# Saved 3D structure 031 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_031'.
# Saved 3D structure 032 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_032'.
# Saved 3D structure 033 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_033'.
# Saved 3D structure 034 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_034'.
# Saved 3D structure 035 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_035'.
# Saved 3D structure 036 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_036'.
# Saved 3D structure 037 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_037'.
# Saved 3D structure 038 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_038'.
# Saved 3D structure 039 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_039'.
# Saved 3D structure 040 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_040'.
# Saved 3D structure 041 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_041'.
# Saved 3D structure 042 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_042'.
# Saved 3D structure 043 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_043'.
# Saved 3D structure 044 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_044'.
# Saved 3D structure 045 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_045'.
# Saved 3D structure 046 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_046'.
# Saved 3D structure 047 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_047'.
# Saved 3D structure 048 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_048'.
# Saved 3D structure 049 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_049'.
# Saved 3D structure 050 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_050'.
# Saved 3D structure 051 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_051'.
# Saved 3D structure 052 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_052'.
# Saved 3D structure 053 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_053'.
# Saved 3D structure 054 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_054'.
# Saved 3D structure 055 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_055'.
# Saved 3D structure 056 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_056'.
# Saved 3D structure 057 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_057'.
# Saved 3D structure 058 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_058'.
# Saved 3D structure 059 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_059'.
# Saved 3D structure 060 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_060'.
# Saved 3D structure 061 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_061'.
# Saved 3D structure 062 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_062'.
# Saved 3D structure 063 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_063'.
# Saved 3D structure 064 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_064'.
# Saved 3D structure 065 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_065'.
# Saved 3D structure 066 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_066'.
# Saved 3D structure 067 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_067'.
# Saved 3D structure 068 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_068'.
# Saved 3D structure 069 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_069'.
# Saved 3D structure 070 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_070'.
# Saved 3D structure 071 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_071'.
# Saved 3D structure 072 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_072'.
# Saved 3D structure 073 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_073'.
# Saved 3D structure 074 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_074'.
# Saved 3D structure 075 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_075'.
# Saved 3D structure 076 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_076'.
# Saved 3D structure 077 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_077'.
# Saved 3D structure 078 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_078'.
# Saved 3D structure 079 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_079'.
# Saved 3D structure 080 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_080'.
# Saved 3D structure 081 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_081'.
# Saved 3D structure 082 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_082'.
# Saved 3D structure 083 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_083'.
# Saved 3D structure 084 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_084'.
# Saved 3D structure 085 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_085'.
# Saved 3D structure 086 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_086'.
# Saved 3D structure 087 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_087'.
# Saved 3D structure 088 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_088'.
# Saved 3D structure 089 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_089'.
# Saved 3D structure 090 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_090'.
# Saved 3D structure 091 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_091'.
# Saved 3D structure 092 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_092'.
# Saved 3D structure 093 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_093'.
# Saved 3D structure 094 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_094'.
# Saved 3D structure 095 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_095'.
# Saved 3D structure 096 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_096'.
# Saved 3D structure 097 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_097'.
# Saved 3D structure 098 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_098'.
# Saved 3D structure 099 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_099'.
# Saved 3D structure 100 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_100'.
# Saved 3D structure 101 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_101'.
# Saved 3D structure 102 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_102'.
# Saved 3D structure 103 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_103'.
# Saved 3D structure 104 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_104'.
# Saved 3D structure 105 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_105'.
# Saved 3D structure 106 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_106'.
# Saved 3D structure 107 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_107'.
# Saved 3D structure 108 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_108'.
# Saved 3D structure 109 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_109'.
# Saved 3D structure 110 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_110'.
# Saved 3D structure 111 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_111'.
# Saved 3D structure 112 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_112'.
# Saved 3D structure 113 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_113'.
# Saved 3D structure 114 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_114'.
# Saved 3D structure 115 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_115'.
# Saved 3D structure 116 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_116'.
# Saved 3D structure 117 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_117'.
# Saved 3D structure 118 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_118'.
# Saved 3D structure 119 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_119'.
# Saved 3D structure 120 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_120'.
# Saved 3D structure 121 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_121'.
# Saved 3D structure 122 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_122'.
# Saved 3D structure 123 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_123'.
# Saved 3D structure 124 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_124'.
# Saved 3D structure 125 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_125'.
# Saved 3D structure 126 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_126'.
# Saved 3D structure 127 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_127'.
# Saved 3D structure 128 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_128'.
# Saved 3D structure 129 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_129'.
# Saved 3D structure 130 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_130'.
# Saved 3D structure 131 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_131'.
# Saved 3D structure 132 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_132'.
# Saved 3D structure 133 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_133'.
# Saved 3D structure 134 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_134'.
# Saved 3D structure 135 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_135'.
# Saved 3D structure 136 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_136'.
# Saved 3D structure 137 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_137'.
# Saved 3D structure 138 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_138'.
# Saved 3D structure 139 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_139'.
# Saved 3D structure 140 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_140'.
# Saved 3D structure 141 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_141'.
# Saved 3D structure 142 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_142'.
# Saved 3D structure 143 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_143'.
# Saved 3D structure 144 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_144'.
# Saved 3D structure 145 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_145'.
# Saved 3D structure 146 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_146'.
# Saved 3D structure 147 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_147'.
# Saved 3D structure 148 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_148'.
# Saved 3D structure 149 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_149'.
# Saved 3D structure 150 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_150'.
# Saved 3D structure 151 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_151'.
# Saved 3D structure 152 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_152'.
# Saved 3D structure 153 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_153'.
# Saved 3D structure 154 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_154'.
# Saved 3D structure 155 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_155'.
# Saved 3D structure 156 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_156'.
# Saved 3D structure 157 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_157'.
# Saved 3D structure 158 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_158'.
# Saved 3D structure 159 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_159'.
# Saved 3D structure 160 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_160'.
# Saved 3D structure 161 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_161'.
# Saved 3D structure 162 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_162'.
# Saved 3D structure 163 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_163'.
# Saved 3D structure 164 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_164'.
# Saved 3D structure 165 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_165'.
# Saved 3D structure 166 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_166'.
# Saved 3D structure 167 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_167'.
# Saved 3D structure 168 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_168'.
# Saved 3D structure 169 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_169'.
# Saved 3D structure 170 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_170'.
# Saved 3D structure 171 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_171'.
# Saved 3D structure 172 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_172'.
# Saved 3D structure 173 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_173'.
# Saved 3D structure 174 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_174'.
# Saved 3D structure 175 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_175'.
# Saved 3D structure 176 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_176'.
# Saved 3D structure 177 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_177'.
# Saved 3D structure 178 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_178'.
# Saved 3D structure 179 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_179'.
# Saved 3D structure 180 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_180'.
# Saved 3D structure 181 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_181'.
# Saved 3D structure 182 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_182'.
# Saved 3D structure 183 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_183'.
# Saved 3D structure 184 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_184'.
# Saved 3D structure 185 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_185'.
# Saved 3D structure 186 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_186'.
# Saved 3D structure 187 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_187'.
# Saved 3D structure 188 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_188'.
# Saved 3D structure 189 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_189'.
# Saved 3D structure 190 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_190'.
# Saved 3D structure 191 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_191'.
# Saved 3D structure 192 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_192'.
# Saved 3D structure 193 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_193'.
# Saved 3D structure 194 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_194'.
# Saved 3D structure 195 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_195'.
# Saved 3D structure 196 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_196'.
# Saved 3D structure 197 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_197'.
# Saved 3D structure 198 with 13 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_198'.
# Saved 3D structure 199 with 15 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_199'.
# Saved 3D structure 200 with 14 cylindrical pores (pore size 12, low_density) in '3D_cirlinder/pore_12x12/low_density/structure_200'.
# Saved 3D structure 001 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_001'.
# Saved 3D structure 002 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_002'.
# Saved 3D structure 003 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_003'.
# Saved 3D structure 004 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_004'.
# Saved 3D structure 005 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_005'.
# Saved 3D structure 006 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_006'.
# Saved 3D structure 007 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_007'.
# Saved 3D structure 008 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_008'.
# Saved 3D structure 009 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_009'.
# Saved 3D structure 010 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_010'.
# Saved 3D structure 011 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_011'.
# Saved 3D structure 012 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_012'.
# Saved 3D structure 013 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_013'.
# Saved 3D structure 014 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_014'.
# Saved 3D structure 015 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_015'.
# Saved 3D structure 016 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_016'.
# Saved 3D structure 017 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_017'.
# Saved 3D structure 018 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_018'.
# Saved 3D structure 019 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_019'.
# Saved 3D structure 020 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_020'.
# Saved 3D structure 021 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_021'.
# Saved 3D structure 022 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_022'.
# Saved 3D structure 023 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_023'.
# Saved 3D structure 024 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_024'.
# Saved 3D structure 025 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_025'.
# Saved 3D structure 026 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_026'.
# Saved 3D structure 027 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_027'.
# Saved 3D structure 028 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_028'.
# Saved 3D structure 029 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_029'.
# Saved 3D structure 030 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_030'.
# Saved 3D structure 031 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_031'.
# Saved 3D structure 032 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_032'.
# Saved 3D structure 033 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_033'.
# Saved 3D structure 034 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_034'.
# Saved 3D structure 035 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_035'.
# Saved 3D structure 036 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_036'.
# Saved 3D structure 037 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_037'.
# Saved 3D structure 038 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_038'.
# Saved 3D structure 039 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_039'.
# Saved 3D structure 040 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_040'.
# Saved 3D structure 041 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_041'.
# Saved 3D structure 042 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_042'.
# Saved 3D structure 043 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_043'.
# Saved 3D structure 044 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_044'.
# Saved 3D structure 045 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_045'.
# Saved 3D structure 046 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_046'.
# Saved 3D structure 047 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_047'.
# Saved 3D structure 048 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_048'.
# Saved 3D structure 049 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_049'.
# Saved 3D structure 050 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_050'.
# Saved 3D structure 051 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_051'.
# Saved 3D structure 052 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_052'.
# Saved 3D structure 053 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_053'.
# Saved 3D structure 054 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_054'.
# Saved 3D structure 055 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_055'.
# Saved 3D structure 056 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_056'.
# Saved 3D structure 057 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_057'.
# Saved 3D structure 058 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_058'.
# Saved 3D structure 059 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_059'.
# Saved 3D structure 060 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_060'.
# Saved 3D structure 061 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_061'.
# Saved 3D structure 062 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_062'.
# Saved 3D structure 063 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_063'.
# Saved 3D structure 064 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_064'.
# Saved 3D structure 065 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_065'.
# Saved 3D structure 066 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_066'.
# Saved 3D structure 067 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_067'.
# Saved 3D structure 068 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_068'.
# Saved 3D structure 069 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_069'.
# Saved 3D structure 070 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_070'.
# Saved 3D structure 071 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_071'.
# Saved 3D structure 072 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_072'.
# Saved 3D structure 073 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_073'.
# Saved 3D structure 074 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_074'.
# Saved 3D structure 075 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_075'.
# Saved 3D structure 076 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_076'.
# Saved 3D structure 077 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_077'.
# Saved 3D structure 078 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_078'.
# Saved 3D structure 079 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_079'.
# Saved 3D structure 080 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_080'.
# Saved 3D structure 081 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_081'.
# Saved 3D structure 082 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_082'.
# Saved 3D structure 083 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_083'.
# Saved 3D structure 084 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_084'.
# Saved 3D structure 085 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_085'.
# Saved 3D structure 086 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_086'.
# Saved 3D structure 087 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_087'.
# Saved 3D structure 088 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_088'.
# Saved 3D structure 089 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_089'.
# Saved 3D structure 090 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_090'.
# Saved 3D structure 091 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_091'.
# Saved 3D structure 092 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_092'.
# Saved 3D structure 093 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_093'.
# Saved 3D structure 094 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_094'.
# Saved 3D structure 095 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_095'.
# Saved 3D structure 096 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_096'.
# Saved 3D structure 097 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_097'.
# Saved 3D structure 098 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_098'.
# Saved 3D structure 099 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_099'.
# Saved 3D structure 100 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_100'.
# Saved 3D structure 101 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_101'.
# Saved 3D structure 102 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_102'.
# Saved 3D structure 103 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_103'.
# Saved 3D structure 104 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_104'.
# Saved 3D structure 105 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_105'.
# Saved 3D structure 106 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_106'.
# Saved 3D structure 107 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_107'.
# Saved 3D structure 108 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_108'.
# Saved 3D structure 109 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_109'.
# Saved 3D structure 110 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_110'.
# Saved 3D structure 111 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_111'.
# Saved 3D structure 112 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_112'.
# Saved 3D structure 113 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_113'.
# Saved 3D structure 114 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_114'.
# Saved 3D structure 115 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_115'.
# Saved 3D structure 116 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_116'.
# Saved 3D structure 117 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_117'.
# Saved 3D structure 118 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_118'.
# Saved 3D structure 119 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_119'.
# Saved 3D structure 120 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_120'.
# Saved 3D structure 121 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_121'.
# Saved 3D structure 122 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_122'.
# Saved 3D structure 123 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_123'.
# Saved 3D structure 124 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_124'.
# Saved 3D structure 125 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_125'.
# Saved 3D structure 126 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_126'.
# Saved 3D structure 127 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_127'.
# Saved 3D structure 128 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_128'.
# Saved 3D structure 129 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_129'.
# Saved 3D structure 130 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_130'.
# Saved 3D structure 131 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_131'.
# Saved 3D structure 132 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_132'.
# Saved 3D structure 133 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_133'.
# Saved 3D structure 134 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_134'.
# Saved 3D structure 135 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_135'.
# Saved 3D structure 136 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_136'.
# Saved 3D structure 137 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_137'.
# Saved 3D structure 138 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_138'.
# Saved 3D structure 139 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_139'.
# Saved 3D structure 140 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_140'.
# Saved 3D structure 141 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_141'.
# Saved 3D structure 142 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_142'.
# Saved 3D structure 143 with 16 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_143'.
# Saved 3D structure 144 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_144'.
# Saved 3D structure 145 with 18 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_145'.
# Saved 3D structure 146 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_146'.
# Saved 3D structure 147 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_147'.
# Saved 3D structure 148 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_148'.
# Saved 3D structure 149 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_149'.
# Saved 3D structure 150 with 20 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_150'.
# Saved 3D structure 151 with 17 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_151'.
# Saved 3D structure 152 with 19 cylindrical pores (pore size 12, medium_density) in '3D_cirlinder/pore_12x12/medium_density/structure_152'.
# ...
# Saved 3D structure 084 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_084'.
# Saved 3D structure 085 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_085'.
# Saved 3D structure 086 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_086'.
# Saved 3D structure 087 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_087'.
# Saved 3D structure 088 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_088'.
# Saved 3D structure 089 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_089'.
# Saved 3D structure 090 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_090'.
# Saved 3D structure 091 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_091'.
# Saved 3D structure 092 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_092'.
# Saved 3D structure 093 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_093'.
# Saved 3D structure 094 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_094'.
# Saved 3D structure 095 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_095'.
# Saved 3D structure 096 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_096'.
# Saved 3D structure 097 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_097'.
# Saved 3D structure 098 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_098'.
# Saved 3D structure 099 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_099'.
# Saved 3D structure 100 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_100'.
# Saved 3D structure 101 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_101'.
# Saved 3D structure 102 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_102'.
# Saved 3D structure 103 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_103'.
# Saved 3D structure 104 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_104'.
# Saved 3D structure 105 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_105'.
# Saved 3D structure 106 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_106'.
# Saved 3D structure 107 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_107'.
# Saved 3D structure 108 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_108'.
# Saved 3D structure 109 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_109'.
# Saved 3D structure 110 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_110'.
# Saved 3D structure 111 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_111'.
# Saved 3D structure 112 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_112'.
# Saved 3D structure 113 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_113'.
# Saved 3D structure 114 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_114'.
# Saved 3D structure 115 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_115'.
# Saved 3D structure 116 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_116'.
# Saved 3D structure 117 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_117'.
# Saved 3D structure 118 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_118'.
# Saved 3D structure 119 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_119'.
# Saved 3D structure 120 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_120'.
# Saved 3D structure 121 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_121'.
# Saved 3D structure 122 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_122'.
# Saved 3D structure 123 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_123'.
# Saved 3D structure 124 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_124'.
# Saved 3D structure 125 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_125'.
# Saved 3D structure 126 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_126'.
# Saved 3D structure 127 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_127'.
# Saved 3D structure 128 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_128'.
# Saved 3D structure 129 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_129'.
# Saved 3D structure 130 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_130'.
# Saved 3D structure 131 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_131'.
# Saved 3D structure 132 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_132'.
# Saved 3D structure 133 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_133'.
# Saved 3D structure 134 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_134'.
# Saved 3D structure 135 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_135'.
# Saved 3D structure 136 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_136'.
# Saved 3D structure 137 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_137'.
# Saved 3D structure 138 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_138'.
# Saved 3D structure 139 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_139'.
# Saved 3D structure 140 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_140'.
# Saved 3D structure 141 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_141'.
# Saved 3D structure 142 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_142'.
# Saved 3D structure 143 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_143'.
# Saved 3D structure 144 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_144'.
# Saved 3D structure 145 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_145'.
# Saved 3D structure 146 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_146'.
# Saved 3D structure 147 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_147'.
# Saved 3D structure 148 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_148'.
# Saved 3D structure 149 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_149'.
# Saved 3D structure 150 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_150'.
# Saved 3D structure 151 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_151'.
# Saved 3D structure 152 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_152'.
# Saved 3D structure 153 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_153'.
# Saved 3D structure 154 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_154'.
# Saved 3D structure 155 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_155'.
# Saved 3D structure 156 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_156'.
# Saved 3D structure 157 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_157'.
# Saved 3D structure 158 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_158'.
# Saved 3D structure 159 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_159'.
# Saved 3D structure 160 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_160'.
# Saved 3D structure 161 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_161'.
# Saved 3D structure 162 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_162'.
# Saved 3D structure 163 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_163'.
# Saved 3D structure 164 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_164'.
# Saved 3D structure 165 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_165'.
# Saved 3D structure 166 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_166'.
# Saved 3D structure 167 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_167'.
# Saved 3D structure 168 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_168'.
# Saved 3D structure 169 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_169'.
# Saved 3D structure 170 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_170'.
# Saved 3D structure 171 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_171'.
# Saved 3D structure 172 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_172'.
# Saved 3D structure 173 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_173'.
# Saved 3D structure 174 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_174'.
# Saved 3D structure 175 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_175'.
# Saved 3D structure 176 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_176'.
# Saved 3D structure 177 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_177'.
# Saved 3D structure 178 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_178'.
# Saved 3D structure 179 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_179'.
# Saved 3D structure 180 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_180'.
# Saved 3D structure 181 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_181'.
# Saved 3D structure 182 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_182'.
# Saved 3D structure 183 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_183'.
# Saved 3D structure 184 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_184'.
# Saved 3D structure 185 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_185'.
# Saved 3D structure 186 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_186'.
# Saved 3D structure 187 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_187'.
# Saved 3D structure 188 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_188'.
# Saved 3D structure 189 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_189'.
# Saved 3D structure 190 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_190'.
# Saved 3D structure 191 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_191'.
# Saved 3D structure 192 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_192'.
# Saved 3D structure 193 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_193'.
# Saved 3D structure 194 with 22 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_194'.
# Saved 3D structure 195 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_195'.
# Saved 3D structure 196 with 24 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_196'.
# Saved 3D structure 197 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_197'.
# Saved 3D structure 198 with 25 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_198'.
# Saved 3D structure 199 with 21 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_199'.
# Saved 3D structure 200 with 23 cylindrical pores (pore size 12, high_density) in '3D_cirlinder/pore_12x12/high_density/structure_200'.
# Generated all 3D porous material structures with cylindrical pores in '3D_cirlinder' folder.
